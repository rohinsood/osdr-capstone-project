# %%
# %%capture
# !pip install import_ipynb --no-cache
import import_ipynb

# %%
# %%capture
m = __import__("Methods")

# %% [markdown]
# # Feature Voting
# - Weighs the importance of features based on the frequency between models, Shapley values, and lowest RMSE

# %%
import pandas as pd
import numpy as np
import ast
from collections import defaultdict
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 60)

# %% [markdown]
# ### Dataset Cleaning

# %%
df = pd.read_csv("data/results/model_results_n3000.csv")

# %%
df
# Out:
#                            Model    Target Variable           MSE        RMSE  \
# 0                 ANN_Final_Test  th_positive_cells   2652.076971   51.498320
# 1   Linear_Regression_Final_Test  th_positive_cells   2042.892604   45.198369
# 2               Ridge_Final_Test  th_positive_cells   2030.433041   45.060327
# 3               Lasso_Final_Test  th_positive_cells   1986.779792   44.573308
# 4                 SVM_Final_Test  th_positive_cells   2038.254701   45.147034
# ..                           ...                ...           ...         ...
# 7   Linear_Regression_Final_Test   repo_glial_cells  50699.446595  225.165376
# 8               Ridge_Final_Test   repo_glial_cells  50730.989891  225.235410
# 9               Lasso_Final_Test   repo_glial_cells  50522.362003  224.771800
# 10                SVM_Final_Test   repo_glial_cells  50717.985908  225.206541
# 11      Random_Forest_Final_Test   repo_glial_cells  50446.581276  224.603164
#
#            MAE        R2   R  \
# 0    28.483265 -0.809668 NaN
# 1    25.071024 -0.393986 NaN
# 2    24.990324 -0.385484 NaN
# 3    24.732177 -0.355697 NaN
# 4    25.050882 -0.390821 NaN
# ..         ...       ...  ..
# 7   104.042219 -0.274177 NaN
# 8   104.083323 -0.274969 NaN
# 9   103.872901 -0.269726 NaN
# 10  104.019568 -0.274643 NaN
# 11  103.685256 -0.267822 NaN
#
#                                               Selected Features  \
# 0   7SLRNA:CR32864,abd-A,Abd-B,Abl,abo,Ace,acj6,nAChRalpha1,...
# 1   Cp38,cv-2,Dab,Dfd,disco,Delta,bsh,ea,Edg78E,Est-P,Taf9,e...
# 2   Fbp1,CG3819,GATAe,CG34002,CG5897,asRNA:CR44106,lncRNA:CR...
# 3   7SLRNA:CR32864,abd-A,Abd-B,Abl,abo,Ace,acj6,nAChRalpha1,...
# 4   Abd-B,acj6,Adh,al,amd,Argk1,Arr1,Arr2,ase,btd,by,c(3)G,C...
# ..                                                          ...
# 7   Cp19,Cp36,cv-2,CycA,CycB,Cyt-b5-r,Dab,dec,Pkg21D,Dip-B,D...
# 8   CG7126,CG43996,CG1387,CG14260,CR30409,asRNA:CR45371,CR43...
# 9   7SLRNA:CR32864,abd-A,Abd-B,Abl,abo,Ace,acj6,nAChRalpha1,...
# 10  7SLRNA:CR32864,Abd-B,Act57B,Gart,Adh,Adhr,al,amd,Amy-p,a...
# 11  7SLRNA:CR32864,abd-A,Abd-B,Abl,abo,Ace,acj6,nAChRalpha1,...
#
#                                              Sorted Shap Values
# 0   {'Fbp1': 0.6175863081031662, 'gammaTry': 0.1568093957583...
# 1   {'CG3819': 0.07599323966654625, 'Dfd': 0.055372169286853...
# 2   {'Fbp1': 0.03646496059075438, 'CG3819': 0.03262355306834...
# 3   {'snk': 0.5626258972541195, 'lncRNA:CR45188': 0.18243525...
# 4   {'Fbp1': 0.032755632660914955, 'CG3819': 0.0297635502707...
# ..                                                          ...
# 7   {'CG7126': 0.03550376790631025, 'Cp36': 0.03255355884668...
# 8   {'CG7126': 0.031388015131363314, 'CG43996': 0.0213343584...
# 9   {'ddbt': 0.43145103942503793, 'prd': 0.2957561177023954,...
# 10  {'djl': 0.035060921352132, 'Tengl3': 0.03152701489366444...
# 11  {'TpnC25D': 0.015189726512469033, 'tutl': 0.015095390673...
#
# [12 rows x 9 columns]

# %%
repo_df = df[df["Target Variable"] == "th_positive_cells"].copy()
repo_df.drop(columns=["Selected Features"], inplace=True)
repo_df
# Out:
#                           Model    Target Variable          MSE       RMSE  \
# 0                ANN_Final_Test  th_positive_cells  2652.076971  51.498320
# 1  Linear_Regression_Final_Test  th_positive_cells  2042.892604  45.198369
# 2              Ridge_Final_Test  th_positive_cells  2030.433041  45.060327
# 3              Lasso_Final_Test  th_positive_cells  1986.779792  44.573308
# 4                SVM_Final_Test  th_positive_cells  2038.254701  45.147034
# 5      Random_Forest_Final_Test  th_positive_cells  2051.461866  45.293066
#
#          MAE        R2   R  \
# 0  28.483265 -0.809668 NaN
# 1  25.071024 -0.393986 NaN
# 2  24.990324 -0.385484 NaN
# 3  24.732177 -0.355697 NaN
# 4  25.050882 -0.390821 NaN
# 5  25.037196 -0.399833 NaN
#
#                                             Sorted Shap Values
# 0  {'Fbp1': 0.6175863081031662, 'gammaTry': 0.1568093957583...
# 1  {'CG3819': 0.07599323966654625, 'Dfd': 0.055372169286853...
# 2  {'Fbp1': 0.03646496059075438, 'CG3819': 0.03262355306834...
# 3  {'snk': 0.5626258972541195, 'lncRNA:CR45188': 0.18243525...
# 4  {'Fbp1': 0.032755632660914955, 'CG3819': 0.0297635502707...
# 5  {'wbl': 0.00345565416948028, 'lncRNA:CR45809': 0.0034556...

# %% [markdown]
# ### RMSE & SHAP Summary Statistics

# %%
# Prepare lists for SHAP values and RMSE
shap_values_list = []
rmse_list = []

for index, row in repo_df.iterrows():
    # Convert SHAP values from string to actual dictionary
    shap_values = ast.literal_eval(row['Sorted Shap Values'])
    
    # Extend the list with the SHAP values
    shap_values_list.extend(shap_values.values())

    # Append the RMSE value
    rmse_list.append(row['RMSE'])

# Convert lists to pandas Series for statistical summary
shap_values_series = pd.Series(shap_values_list)
rmse_series = pd.Series(rmse_list)

# Display summary statistics
shap_stats = shap_values_series.describe()
rmse_stats = rmse_series.describe()

print("Summary Statistics for SHAP Values:")
print(shap_stats)
print("\nSummary Statistics for RMSE:")
print(rmse_stats)
# Out:
# Summary Statistics for SHAP Values:
# count    18000.000000
# mean         0.000733
# std          0.006868
# min          0.000000
# 25%          0.000000
# 50%          0.000055
# 75%          0.000364
# max          0.617586
# dtype: float64
#
# Summary Statistics for RMSE:
# count     6.000000
# mean     46.128404
# std       2.642762
# min      44.573308
# 25%      45.082004
# 50%      45.172702
# 75%      45.269392
# max      51.498320
# dtype: float64

# %% [markdown]
# ### Ensemble Feature Voting Implementation

# %%
from collections import defaultdict
import pandas as pd
import ast
import numpy as np

# Create dictionaries to store feature importance and frequency
feature_importance = defaultdict(float)
feature_frequency = defaultdict(float)

# Extract RMSE, R², and SHAP values
rmse_values = repo_df['RMSE'].values
r2_values = repo_df['R2'].values

# Normalize RMSE and R² using min-max scaling
rmse_min, rmse_max = min(rmse_values), max(rmse_values)
r2_min, r2_max = min(r2_values), max(r2_values)

repo_df['RMSE_scaled'] = (repo_df['RMSE'] - rmse_min) / (rmse_max - rmse_min)
repo_df['R2_scaled'] = (repo_df['R2'] - r2_min) / (r2_max - r2_min)

# Loop through the DataFrame and calculate importance
for index, row in repo_df.iterrows():
    shap_values = row['Sorted Shap Values']
    
    # Convert SHAP values from string to dictionary
    shap_values = ast.literal_eval(shap_values)
    
    # Normalize SHAP values (min-max scaling per model)
    shap_array = np.array(list(shap_values.values()))
    shap_min, shap_max = shap_array.min(), shap_array.max()
    
    if shap_max > shap_min:  # Avoid division by zero
        shap_values = {k: (v - shap_min) / (shap_max - shap_min) for k, v in shap_values.items()}
    
    # Scaled RMSE and R²
    rmse_scaled = row['RMSE_scaled']
    r2_scaled = row['R2_scaled']
    
    # Weight adjustment by (1 + R²_scaled) to emphasize models with higher R²
    weight_adjustment = (1 + r2_scaled)

    # SHAP importance scaling
    for feature, shap_value in shap_values.items():
        if shap_value != 0:
            feature_importance[feature] += shap_value * weight_adjustment
            feature_frequency[feature] += (1 / (rmse_scaled + 1e-6)) * weight_adjustment  # Avoid division by zero

# Adjust final importance by multiplying by the RMSE and R²-weighted frequency
for feature in feature_importance:
    feature_importance[feature] *= feature_frequency[feature]

# Sort features by their adjusted importance scores
sorted_features = sorted(feature_importance.items(), key=lambda item: item[1], reverse=True)

# Create a DataFrame for the top 20 features
df_sorted_features = pd.DataFrame(sorted_features, columns=['Gene', 'Weight'])

# Display the top 20 important features
df_sorted_features.head(20)

df_sorted_features.to_csv("test test.csv", index=False)

# %%
df_sorted_features.head(20)
# Out:
#               Gene        Weight
# 0              snk  4.057546e+06
# 1   lncRNA:CR45188  1.341210e+06
# 2          CG46388  9.433750e+05
# 3              prd  8.014938e+05
# 4             Fbp1  4.158262e+02
# 5           CG3819  3.879623e+02
# 6           CG9411  2.349030e+02
# 7          CG34002  2.220437e+02
# 8          CR43281  1.961197e+02
# 9           CG5897  1.791819e+02
# 10         CG43645  1.733407e+02
# 11   asRNA:CR44106  1.486162e+02
# 12  lncRNA:CR44761  1.114170e+02
# 13         CG15649  1.074189e+02
# 14  lncRNA:CR32730  1.051065e+02
# 15         CG18480  1.039205e+02
# 16             Dfd  1.026808e+02
# 17            Ir7c  9.950048e+01
# 18           GATAe  9.807217e+01
# 19   asRNA:CR45135  9.319388e+01

# %% [markdown]
# # Gene Set Analysis

# %%
# look at the names of the libraries that are available to use for PEA and GSEA
gene_sets = m.gp.get_library_name(organism="fly")

gene_sets.remove("Allele_Phenotypes_from_FlyBase_2017")

gene_list = df_sorted_features[:20]['Gene'].tolist()

# %%
# Perform GO enrichment analysis with FlyBase genes using Enrichr
enr = m.gp.enrichr(
    gene_list=gene_list,  # List of FlyBase gene symbols
    gene_sets=gene_sets,
    organism='fly',  # Set to 'fly' for Drosophila (FlyBase genes)
    outdir=None
)

enr.results[enr.results['Adjusted P-value'] < 0.05][['Term', 'Genes', 'Adjusted P-value']]
# Out:
#                                                                                                                              Term  \
# 0                                                                                                          subesophageal ganglion
# 1                                                                                                    embryonic mandibular segment
# 2                                                                       intestinal stem cell of posterior adult midgut epithelium
# 3                                                                                                     embryonic maxillary segment
# 4                                                                                                                       vibrissae
# 5                                                                                                                 lateral process
# 6                                                                                                             hypostomal sclerite
# 7                                                                                                             pair rule phenotype
# 8                                                                                                                            poor
# 9                                                                                                                       wild-type
# 10                                                                                                               maxillary palpus
# 11                                                                                                                    mouth hooks
# 15                                                                                                                  denticle belt
# 71                                                                                                                            gut
# 72                                                                                                             vitelline_membrane
# 73                                                                                                                 proventriculus
# 74                                                                                                                         embryo
# 75                                                                                                       male_reproductive_system
# 82                                                                                                       proteolysis (GO:0006508)
# 83                                                                                           lipid catabolic process (GO:0016042)
# 84                                                                                                  cold acclimation (GO:0009631)
# 85                                                                                     ceramide biosynthetic process (GO:0046513)
# 86                                                                                           protein deglycosylation (GO:0006517)
# 87                                                                                        intracellular pH reduction (GO:0051452)
# 88                                                                                         mannose metabolic process (GO:0006013)
# 89                                                                                    sphingolipid catabolic process (GO:0030149)
# 90                                                                                     vesicle budding from membrane (GO:0006900)
# 91                                                                                             inflammatory response (GO:0006954)
# 92                                                                              toll-like receptor signaling pathway (GO:0002224)
# 93                                                                                            vacuolar acidification (GO:0007035)
# 94                                                                                                   anion transport (GO:0006820)
# 95                                                                                        amide biosynthetic process (GO:0043604)
# 96                                                                                      endothelial cell development (GO:0001885)
# 97                                                                         organonitrogen compound catabolic process (GO:1901565)
# 98                                                                         cellular transition metal ion homeostasis (GO:0046916)
# 99                                                                                    phospholipid catabolic process (GO:0009395)
# 100                                                                              neuroendocrine cell differentiation (GO:0061101)
# 101                                                                   negative regulation of immune effector process (GO:0002698)
# 102                                                       negative regulation of natural killer cell differentiation (GO:0032824)
# 103                                                                                            metal ion homeostasis (GO:0055065)
# 104                                                                                                  amide transport (GO:0042886)
# 105                                    regulation of natural killer cell differentiation involved in immune response (GO:0032826)
# 106                                                                                        inorganic ion homeostasis (GO:0098771)
# 107                                                                             neuroepithelial cell differentiation (GO:0060563)
# 108                                                                                             copper ion transport (GO:0006825)
# 109                                                                                       ceramide metabolic process (GO:0006672)
# 110                                                                                        carboxylic acid transport (GO:0046942)
# 111                                                                                          renal tubular secretion (GO:0097254)
# 112                                                                               nucleoside transmembrane transport (GO:1901642)
# 113                                                                                             nucleoside transport (GO:0015858)
# 114                                                                                       phospholipid translocation (GO:0045332)
# 115                                                                              glycosaminoglycan catabolic process (GO:0006027)
# 116                                                                                              lipid translocation (GO:0034204)
# 117                                                                                           response to copper ion (GO:0046688)
# 118                                                                                  peptidoglycan metabolic process (GO:0000270)
# 119                                                                                  peptidoglycan catabolic process (GO:0009253)
# 120                                                                                          organic anion transport (GO:0015711)
# 121                                                                                   regulation of actin nucleation (GO:0051125)
# 122                                                                                        peptide catabolic process (GO:0043171)
# 123                                                                                oligosaccharide metabolic process (GO:0009311)
# 124                                                                 fatty acid beta-oxidation using acyl-CoA oxidase (GO:0033540)
# 125                                                                                             cell-matrix adhesion (GO:0007160)
# 126                                                           fatty acid beta-oxidation using acyl-CoA dehydrogenase (GO:0033539)
# 127                                                                                             response to zinc ion (GO:0010043)
# 128                                                                                        peptide metabolic process (GO:0006518)
# 129                                                                                  sulfate transmembrane transport (GO:1902358)
# 130                                                                       sodium-independent organic anion transport (GO:0043252)
# 131                                                                               nucleotide-sugar metabolic process (GO:0009225)
# 132                                                                                            response to metal ion (GO:0010038)
# 133                                                                                         larval heart development (GO:0007508)
# 134                           negative regulation of natural killer cell differentiation involved in immune response (GO:0032827)
# 135                                                                                oligosaccharide catabolic process (GO:0009313)
# 186                                                                     proton-transporting V-type ATPase, V1 domain (GO:0033180)
# 187                                                                        proton-transporting V-type ATPase complex (GO:0033176)
# 188                                                        plasma membrane proton-transporting V-type ATPase complex (GO:0033181)
# 189                                                            vacuolar proton-transporting V-type ATPase, V1 domain (GO:0000221)
# 190                                                               vacuolar proton-transporting V-type ATPase complex (GO:0016471)
# 191                                                                                          smooth septate junction (GO:0005920)
# 256                                                                                             endoderm development (GO:0007492)
# 257                                                                        glandular epithelial cell differentiation (GO:0002067)
# 258                                                                             enteroendocrine cell differentiation (GO:0035883)
# 259                                         maternal specification of dorsal/ventral axis, oocyte, germ-line encoded (GO:0007311)
# 260                                                                                     digestive system development (GO:0055123)
# 261                                                 positive regulation of apoptotic process involved in development (GO:1904747)
# 262                                                                          periodic partitioning by pair rule gene (GO:0007366)
# 263                                                                        specification of segmental identity, head (GO:0007380)
# 266                                                                         anterior/posterior pattern specification (GO:0009952)
# 278                                             positive regulation of transcription from RNA polymerase II promoter (GO:0045944)
# 279                                                              positive regulation of transcription, DNA-templated (GO:0045893)
# 281                                                                                    regulation of gene expression (GO:0010468)
# 675                                                                                           protein_kinase_complex_(GO:1902911)
# 678                       transcription factor activity, RNA polymerase II distal enhancer sequence-specific binding (GO:0003705)
# 680                                                RNA polymerase II regulatory region sequence-specific DNA binding (GO:0000977)
# 682  transcriptional activator activity, RNA polymerase II transcription regulatory region sequence-specific binding (GO:0001228)
# 684                                                                  RNA polymerase II regulatory region DNA binding (GO:0001012)
# 734                                                                                 solute:proton_symporter_activity_(GO:0015295)
# 762                                                                                                               prostate cancer
# 763                                                                                                        Hemocyanin, C-terminal
# 764                                                                                                        Hemocyanin, N-terminal
# 765                                                                                              Serine proteases, trypsin domain
# 766                                                                                                      Homeobox domain, metazoa
# 767                                                                                            Proteinase, regulatory CLIP domain
# 768                                                                                                                 Paired domain
# 769                                                                                                               Homeobox domain
# 770                                                                                                                       Cpr100A
# 771                                                                                                                        Dscam2
# 772                                                                                                                        CG4452
# 773                                                                                                                         CanB2
# 774                                                                                                                         KP78b
# 775                                                                                                                       CG16743
# 776                                                                                                                       CG14400
# 777                                                                                                                       CG15027
# 778                                                                                                                           png
# 779                                                                                                                       CG10987
# 780                                                                                                                          Cdk2
# 781                                                                                                                        Cks85A
# 782                                                                                                                       CG42749
# 783                                                                                                                       CG14921
# 784                                                                                                                        CG9527
# 785                                                                                                                       CG13390
# 786                                                                                                                        CG3703
# 787                                                                                                                          gukh
# 788                                                                                                                          sstn
# 789                                                                                                                       CG13996
# 790                                                                                                                           sav
# 792                                                                                                                         Hsp26
# 793                                                                                                                          Gbp2
# 794                                                                                                                       CG18600
# 795                                                                                                                        CG7548
# 798                                                                                                                       Cpr49Af
# 800                                                                                                                       CG12902
# 801                                                                                                                       CG10898
# 802                                                                                                                           Sxl
# 808                                                                                                                         Rassf
# 812                                                                                                                         PGAP5
# 820                                                                                                                  Hemocyanin_C
# 821                                                                                                                  Hemocyanin_N
# 822                                                                                                                       Trypsin
# 823                                                                                                                           PAX
# 824                                                                                                                   Homeodomain
#
#                     Genes  Adjusted P-value
# 0                     Dfd          0.042423
# 1                     Dfd          0.042423
# 2                   GATAe          0.042423
# 3                     Dfd          0.042423
# 4                     Dfd          0.042423
# 5                     Dfd          0.042423
# 6                     Dfd          0.044523
# 7                     prd          0.042423
# 8                     Dfd          0.047547
# 9                     prd          0.047547
# 10                    Dfd          0.048666
# 11                    Dfd          0.049604
# 15                snk;prd          0.042423
# 71                  GATAe          0.039924
# 72                    snk          0.045788
# 73                  GATAe          0.045788
# 74                  GATAe          0.045788
# 75                    prd          0.045788
# 82   CG3819;CG18480;GATAe          0.007924
# 83   CG3819;CG18480;GATAe          0.007924
# 84   CG3819;CG18480;GATAe          0.007924
# 85   CG3819;CG18480;GATAe          0.007924
# 86   CG3819;CG18480;GATAe          0.007924
# 87   CG3819;CG18480;GATAe          0.007924
# 88   CG3819;CG18480;GATAe          0.007924
# 89   CG3819;CG18480;GATAe          0.007924
# 90   CG3819;CG18480;GATAe          0.007924
# 91   CG3819;CG18480;GATAe          0.007924
# 92   CG3819;CG18480;GATAe          0.007924
# 93   CG3819;CG18480;GATAe          0.007924
# 94   CG3819;CG18480;GATAe          0.007924
# 95          CG18480;GATAe          0.032346
# 96          CG18480;GATAe          0.032346
# 97          CG18480;GATAe          0.032346
# 98          CG18480;GATAe          0.032346
# 99         CG3819;CG18480          0.032346
# 100         CG18480;GATAe          0.032346
# 101         CG18480;GATAe          0.032346
# 102         CG18480;GATAe          0.032346
# 103         CG18480;GATAe          0.032346
# 104         CG18480;GATAe          0.032346
# 105         CG18480;GATAe          0.032346
# 106         CG18480;GATAe          0.032346
# 107         CG18480;GATAe          0.032346
# 108         CG18480;GATAe          0.032346
# 109         CG18480;GATAe          0.032346
# 110         CG18480;GATAe          0.032346
# 111         CG18480;GATAe          0.032346
# 112         CG18480;GATAe          0.032346
# 113         CG18480;GATAe          0.032346
# 114         CG18480;GATAe          0.032346
# 115         CG18480;GATAe          0.032346
# 116         CG18480;GATAe          0.032346
# 117         CG18480;GATAe          0.032346
# 118         CG18480;GATAe          0.032346
# 119         CG18480;GATAe          0.032346
# 120         CG18480;GATAe          0.032346
# 121         CG18480;GATAe          0.032346
# 122         CG18480;GATAe          0.032346
# 123         CG18480;GATAe          0.032346
# 124         CG18480;GATAe          0.032346
# 125         CG18480;GATAe          0.032346
# 126         CG18480;GATAe          0.032346
# 127         CG18480;GATAe          0.032346
# 128         CG18480;GATAe          0.032346
# 129        CG3819;CG18480          0.032346
# 130         CG18480;GATAe          0.032346
# 131         CG18480;GATAe          0.032346
# 132         CG18480;GATAe          0.032346
# 133         CG18480;GATAe          0.032346
# 134         CG18480;GATAe          0.032346
# 135         CG18480;GATAe          0.032346
# 186          CG3819;GATAe          0.044787
# 187          CG3819;GATAe          0.044787
# 188          CG3819;GATAe          0.044787
# 189          CG3819;GATAe          0.044787
# 190          CG3819;GATAe          0.044787
# 191          CG3819;GATAe          0.044787
# 256                 GATAe          0.039450
# 257                 GATAe          0.039450
# 258                 GATAe          0.039450
# 259                   snk          0.039450
# 260                 GATAe          0.039450
# 261                   Dfd          0.039450
# 262                   prd          0.039450
# 263                   Dfd          0.043771
# 266               prd;Dfd          0.039450
# 278         prd;Dfd;GATAe          0.039450
# 279         prd;Dfd;GATAe          0.039450
# 281         prd;Dfd;GATAe          0.040717
# 675             Dfd;GATAe          0.005820
# 678               prd;Dfd          0.019677
# 680         prd;Dfd;GATAe          0.019677
# 682             Dfd;GATAe          0.028223
# 684               prd;Dfd          0.038792
# 734  CG3819;CG18480;GATAe          0.015849
# 762                   prd          0.008966
# 763                  Fbp1          0.011163
# 764                  Fbp1          0.011163
# 765                   snk          0.027644
# 766                   Dfd          0.027644
# 767                   snk          0.011163
# 768                   prd          0.011163
# 769               Dfd;prd          0.010270
# 770                CG9411          0.049294
# 771                   prd          0.049294
# 772                   prd          0.049294
# 773                   prd          0.049294
# 774                   Dfd          0.049294
# 775                   prd          0.049294
# 776                   prd          0.049294
# 777                   prd          0.049294
# 778                   Dfd          0.049294
# 779                   prd          0.049294
# 780               prd;Dfd          0.049294
# 781                   Dfd          0.049294
# 782                   prd          0.049294
# 783                   prd          0.049294
# 784                   Dfd          0.049294
# 785                   prd          0.049294
# 786                   prd          0.049294
# 787                CG9411          0.049294
# 788                CG9411          0.049294
# 789                   Dfd          0.049294
# 790                CG9411          0.049294
# 792               CG15649          0.049294
# 793                   prd          0.049294
# 794                   prd          0.049294
# 795                CG9411          0.049294
# 798                CG9411          0.049294
# 800                   prd          0.049294
# 801                   prd          0.049294
# 802                   prd          0.049294
# 808                   prd          0.049294
# 812                   Dfd          0.049294
# 820                  Fbp1          0.008725
# 821                  Fbp1          0.008725
# 822                   snk          0.027644
# 823                   prd          0.008725
# 824               Dfd;prd          0.006589

# %%
results = enr.results[enr.results['Adjusted P-value'] < 0.05][['Term', 'Genes', 'Adjusted P-value']].sort_values(by=['Adjusted P-value'], ascending=False)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
results
# Out:
#                                                                                                                              Term  \
# 11                                                                                                                    mouth hooks
# 795                                                                                                                        CG7548
# 800                                                                                                                       CG12902
# 798                                                                                                                       Cpr49Af
# 801                                                                                                                       CG10898
# 776                                                                                                                       CG14400
# 777                                                                                                                       CG15027
# 784                                                                                                                        CG9527
# 785                                                                                                                       CG13390
# 770                                                                                                                       Cpr100A
# 771                                                                                                                        Dscam2
# 772                                                                                                                        CG4452
# 773                                                                                                                         CanB2
# 774                                                                                                                         KP78b
# 775                                                                                                                       CG16743
# 778                                                                                                                           png
# 779                                                                                                                       CG10987
# 780                                                                                                                          Cdk2
# 781                                                                                                                        Cks85A
# 782                                                                                                                       CG42749
# 783                                                                                                                       CG14921
# 802                                                                                                                           Sxl
# 808                                                                                                                         Rassf
# 812                                                                                                                         PGAP5
# 786                                                                                                                        CG3703
# 787                                                                                                                          gukh
# 788                                                                                                                          sstn
# 789                                                                                                                       CG13996
# 790                                                                                                                           sav
# 792                                                                                                                         Hsp26
# 793                                                                                                                          Gbp2
# 794                                                                                                                       CG18600
# 10                                                                                                               maxillary palpus
# 9                                                                                                                       wild-type
# 8                                                                                                                            poor
# 72                                                                                                             vitelline_membrane
# 74                                                                                                                         embryo
# 73                                                                                                                 proventriculus
# 75                                                                                                       male_reproductive_system
# 189                                                            vacuolar proton-transporting V-type ATPase, V1 domain (GO:0000221)
# 190                                                               vacuolar proton-transporting V-type ATPase complex (GO:0016471)
# 188                                                        plasma membrane proton-transporting V-type ATPase complex (GO:0033181)
# 187                                                                        proton-transporting V-type ATPase complex (GO:0033176)
# 191                                                                                          smooth septate junction (GO:0005920)
# 186                                                                     proton-transporting V-type ATPase, V1 domain (GO:0033180)
# 6                                                                                                             hypostomal sclerite
# 263                                                                        specification of segmental identity, head (GO:0007380)
# 2                                                                       intestinal stem cell of posterior adult midgut epithelium
# 1                                                                                                    embryonic mandibular segment
# 0                                                                                                          subesophageal ganglion
# 4                                                                                                                       vibrissae
# 5                                                                                                                 lateral process
# 3                                                                                                     embryonic maxillary segment
# 7                                                                                                             pair rule phenotype
# 15                                                                                                                  denticle belt
# 281                                                                                    regulation of gene expression (GO:0010468)
# 71                                                                                                                            gut
# 258                                                                             enteroendocrine cell differentiation (GO:0035883)
# 259                                         maternal specification of dorsal/ventral axis, oocyte, germ-line encoded (GO:0007311)
# 266                                                                         anterior/posterior pattern specification (GO:0009952)
# 278                                             positive regulation of transcription from RNA polymerase II promoter (GO:0045944)
# 261                                                 positive regulation of apoptotic process involved in development (GO:1904747)
# 262                                                                          periodic partitioning by pair rule gene (GO:0007366)
# 260                                                                                     digestive system development (GO:0055123)
# 279                                                              positive regulation of transcription, DNA-templated (GO:0045893)
# 256                                                                                             endoderm development (GO:0007492)
# 257                                                                        glandular epithelial cell differentiation (GO:0002067)
# 684                                                                  RNA polymerase II regulatory region DNA binding (GO:0001012)
# 95                                                                                        amide biosynthetic process (GO:0043604)
# 120                                                                                          organic anion transport (GO:0015711)
# 121                                                                                   regulation of actin nucleation (GO:0051125)
# 122                                                                                        peptide catabolic process (GO:0043171)
# 123                                                                                oligosaccharide metabolic process (GO:0009311)
# 124                                                                 fatty acid beta-oxidation using acyl-CoA oxidase (GO:0033540)
# 125                                                                                             cell-matrix adhesion (GO:0007160)
# 126                                                           fatty acid beta-oxidation using acyl-CoA dehydrogenase (GO:0033539)
# 135                                                                                oligosaccharide catabolic process (GO:0009313)
# 127                                                                                             response to zinc ion (GO:0010043)
# 112                                                                               nucleoside transmembrane transport (GO:1901642)
# 114                                                                                       phospholipid translocation (GO:0045332)
# 113                                                                                             nucleoside transport (GO:0015858)
# 116                                                                                              lipid translocation (GO:0034204)
# 117                                                                                           response to copper ion (GO:0046688)
# 118                                                                                  peptidoglycan metabolic process (GO:0000270)
# 115                                                                              glycosaminoglycan catabolic process (GO:0006027)
# 119                                                                                  peptidoglycan catabolic process (GO:0009253)
# 97                                                                         organonitrogen compound catabolic process (GO:1901565)
# 98                                                                         cellular transition metal ion homeostasis (GO:0046916)
# 99                                                                                    phospholipid catabolic process (GO:0009395)
# 100                                                                              neuroendocrine cell differentiation (GO:0061101)
# 101                                                                   negative regulation of immune effector process (GO:0002698)
# 102                                                       negative regulation of natural killer cell differentiation (GO:0032824)
# 103                                                                                            metal ion homeostasis (GO:0055065)
# 104                                                                                                  amide transport (GO:0042886)
# 105                                    regulation of natural killer cell differentiation involved in immune response (GO:0032826)
# 106                                                                                        inorganic ion homeostasis (GO:0098771)
# 107                                                                             neuroepithelial cell differentiation (GO:0060563)
# 108                                                                                             copper ion transport (GO:0006825)
# 109                                                                                       ceramide metabolic process (GO:0006672)
# 110                                                                                        carboxylic acid transport (GO:0046942)
# 111                                                                                          renal tubular secretion (GO:0097254)
# 96                                                                                      endothelial cell development (GO:0001885)
# 128                                                                                        peptide metabolic process (GO:0006518)
# 129                                                                                  sulfate transmembrane transport (GO:1902358)
# 130                                                                       sodium-independent organic anion transport (GO:0043252)
# 131                                                                               nucleotide-sugar metabolic process (GO:0009225)
# 132                                                                                            response to metal ion (GO:0010038)
# 133                                                                                         larval heart development (GO:0007508)
# 134                           negative regulation of natural killer cell differentiation involved in immune response (GO:0032827)
# 682  transcriptional activator activity, RNA polymerase II transcription regulatory region sequence-specific binding (GO:0001228)
# 765                                                                                              Serine proteases, trypsin domain
# 766                                                                                                      Homeobox domain, metazoa
# 822                                                                                                                       Trypsin
# 678                       transcription factor activity, RNA polymerase II distal enhancer sequence-specific binding (GO:0003705)
# 680                                                RNA polymerase II regulatory region sequence-specific DNA binding (GO:0000977)
# 734                                                                                 solute:proton_symporter_activity_(GO:0015295)
# 763                                                                                                        Hemocyanin, C-terminal
# 768                                                                                                                 Paired domain
# 764                                                                                                        Hemocyanin, N-terminal
# 767                                                                                            Proteinase, regulatory CLIP domain
# 769                                                                                                               Homeobox domain
# 762                                                                                                               prostate cancer
# 820                                                                                                                  Hemocyanin_C
# 821                                                                                                                  Hemocyanin_N
# 823                                                                                                                           PAX
# 84                                                                                                  cold acclimation (GO:0009631)
# 86                                                                                           protein deglycosylation (GO:0006517)
# 83                                                                                           lipid catabolic process (GO:0016042)
# 87                                                                                        intracellular pH reduction (GO:0051452)
# 85                                                                                     ceramide biosynthetic process (GO:0046513)
# 88                                                                                         mannose metabolic process (GO:0006013)
# 89                                                                                    sphingolipid catabolic process (GO:0030149)
# 93                                                                                            vacuolar acidification (GO:0007035)
# 90                                                                                     vesicle budding from membrane (GO:0006900)
# 91                                                                                             inflammatory response (GO:0006954)
# 92                                                                              toll-like receptor signaling pathway (GO:0002224)
# 82                                                                                                       proteolysis (GO:0006508)
# 94                                                                                                   anion transport (GO:0006820)
# 824                                                                                                                   Homeodomain
# 675                                                                                           protein_kinase_complex_(GO:1902911)
#
#                     Genes  Adjusted P-value
# 11                    Dfd          0.049604
# 795                CG9411          0.049294
# 800                   prd          0.049294
# 798                CG9411          0.049294
# 801                   prd          0.049294
# 776                   prd          0.049294
# 777                   prd          0.049294
# 784                   Dfd          0.049294
# 785                   prd          0.049294
# 770                CG9411          0.049294
# 771                   prd          0.049294
# 772                   prd          0.049294
# 773                   prd          0.049294
# 774                   Dfd          0.049294
# 775                   prd          0.049294
# 778                   Dfd          0.049294
# 779                   prd          0.049294
# 780               prd;Dfd          0.049294
# 781                   Dfd          0.049294
# 782                   prd          0.049294
# 783                   prd          0.049294
# 802                   prd          0.049294
# 808                   prd          0.049294
# 812                   Dfd          0.049294
# 786                   prd          0.049294
# 787                CG9411          0.049294
# 788                CG9411          0.049294
# 789                   Dfd          0.049294
# 790                CG9411          0.049294
# 792               CG15649          0.049294
# 793                   prd          0.049294
# 794                   prd          0.049294
# 10                    Dfd          0.048666
# 9                     prd          0.047547
# 8                     Dfd          0.047547
# 72                    snk          0.045788
# 74                  GATAe          0.045788
# 73                  GATAe          0.045788
# 75                    prd          0.045788
# 189          CG3819;GATAe          0.044787
# 190          CG3819;GATAe          0.044787
# 188          CG3819;GATAe          0.044787
# 187          CG3819;GATAe          0.044787
# 191          CG3819;GATAe          0.044787
# 186          CG3819;GATAe          0.044787
# 6                     Dfd          0.044523
# 263                   Dfd          0.043771
# 2                   GATAe          0.042423
# 1                     Dfd          0.042423
# 0                     Dfd          0.042423
# 4                     Dfd          0.042423
# 5                     Dfd          0.042423
# 3                     Dfd          0.042423
# 7                     prd          0.042423
# 15                snk;prd          0.042423
# 281         prd;Dfd;GATAe          0.040717
# 71                  GATAe          0.039924
# 258                 GATAe          0.039450
# 259                   snk          0.039450
# 266               prd;Dfd          0.039450
# 278         prd;Dfd;GATAe          0.039450
# 261                   Dfd          0.039450
# 262                   prd          0.039450
# 260                 GATAe          0.039450
# 279         prd;Dfd;GATAe          0.039450
# 256                 GATAe          0.039450
# 257                 GATAe          0.039450
# 684               prd;Dfd          0.038792
# 95          CG18480;GATAe          0.032346
# 120         CG18480;GATAe          0.032346
# 121         CG18480;GATAe          0.032346
# 122         CG18480;GATAe          0.032346
# 123         CG18480;GATAe          0.032346
# 124         CG18480;GATAe          0.032346
# 125         CG18480;GATAe          0.032346
# 126         CG18480;GATAe          0.032346
# 135         CG18480;GATAe          0.032346
# 127         CG18480;GATAe          0.032346
# 112         CG18480;GATAe          0.032346
# 114         CG18480;GATAe          0.032346
# 113         CG18480;GATAe          0.032346
# 116         CG18480;GATAe          0.032346
# 117         CG18480;GATAe          0.032346
# 118         CG18480;GATAe          0.032346
# 115         CG18480;GATAe          0.032346
# 119         CG18480;GATAe          0.032346
# 97          CG18480;GATAe          0.032346
# 98          CG18480;GATAe          0.032346
# 99         CG3819;CG18480          0.032346
# 100         CG18480;GATAe          0.032346
# 101         CG18480;GATAe          0.032346
# 102         CG18480;GATAe          0.032346
# 103         CG18480;GATAe          0.032346
# 104         CG18480;GATAe          0.032346
# 105         CG18480;GATAe          0.032346
# 106         CG18480;GATAe          0.032346
# 107         CG18480;GATAe          0.032346
# 108         CG18480;GATAe          0.032346
# 109         CG18480;GATAe          0.032346
# 110         CG18480;GATAe          0.032346
# 111         CG18480;GATAe          0.032346
# 96          CG18480;GATAe          0.032346
# 128         CG18480;GATAe          0.032346
# 129        CG3819;CG18480          0.032346
# 130         CG18480;GATAe          0.032346
# 131         CG18480;GATAe          0.032346
# 132         CG18480;GATAe          0.032346
# 133         CG18480;GATAe          0.032346
# 134         CG18480;GATAe          0.032346
# 682             Dfd;GATAe          0.028223
# 765                   snk          0.027644
# 766                   Dfd          0.027644
# 822                   snk          0.027644
# 678               prd;Dfd          0.019677
# 680         prd;Dfd;GATAe          0.019677
# 734  CG3819;CG18480;GATAe          0.015849
# 763                  Fbp1          0.011163
# 768                   prd          0.011163
# 764                  Fbp1          0.011163
# 767                   snk          0.011163
# 769               Dfd;prd          0.010270
# 762                   prd          0.008966
# 820                  Fbp1          0.008725
# 821                  Fbp1          0.008725
# 823                   prd          0.008725
# 84   CG3819;CG18480;GATAe          0.007924
# 86   CG3819;CG18480;GATAe          0.007924
# 83   CG3819;CG18480;GATAe          0.007924
# 87   CG3819;CG18480;GATAe          0.007924
# 85   CG3819;CG18480;GATAe          0.007924
# 88   CG3819;CG18480;GATAe          0.007924
# 89   CG3819;CG18480;GATAe          0.007924
# 93   CG3819;CG18480;GATAe          0.007924
# 90   CG3819;CG18480;GATAe          0.007924
# 91   CG3819;CG18480;GATAe          0.007924
# 92   CG3819;CG18480;GATAe          0.007924
# 82   CG3819;CG18480;GATAe          0.007924
# 94   CG3819;CG18480;GATAe          0.007924
# 824               Dfd;prd          0.006589
# 675             Dfd;GATAe          0.005820

# %% [markdown]
# # Pathway Analysis Prep

# %%
symbols = df_sorted_features["Gene"].to_list()

import pandas as pd

# Load the conversion DataFrame
conversion_df = pd.read_csv("data/datasets/conversion_df.csv")

# Assuming the columns in conversion_df are named 'GeneSymbol' and 'FlyBaseID'
# If they have different names, adjust accordingly.
conversion_dict = dict(zip(conversion_df['Gene Symbol'], conversion_df['FB ID']))

# Assuming `symbols` contains the gene symbols
flybase_ids = [conversion_dict.get(symbol) for symbol in symbols]

# Now `flybase_ids` contains the FlyBase IDs corresponding to the gene symbols.
flybase_ids[:20]
# Out:
# ['FBgn0003450',
#  'FBgn0266698',
#  'FBgn0286834',
#  'FBgn0003145',
#  'FBgn0000639',
#  'FBgn0036833',
#  'FBgn0030569',
#  'FBgn0054002',
#  'FBgn0262970',
#  'FBgn0036220',
#  'FBgn0263654',
#  'FBgn0264915',
#  'FBgn0265982',
#  'FBgn0034563',
#  'FBgn0047092',
#  'FBgn0028518',
#  'FBgn0000439',
#  'FBgn0029966',
#  'FBgn0038391',
#  'FBgn0266628']

# %%
# Specify the output file name
output_file = "background_genes.txt"

# Write the FlyBase IDs to the text file
with open(output_file, 'w') as file:
    for fb_id in conversion_df["FB ID"]:
        file.write(f"{fb_id}\n")

print(f"FlyBase IDs have been written to {output_file}")
# Out:
# FlyBase IDs have been written to background_genes.txt

# %%
# Specify the output file name
output_file = "th_selected_genes.txt"

# Write the FlyBase IDs to the text file
with open(output_file, 'w') as file:
    for fb_id in flybase_ids:
        file.write(f"{fb_id}\n")

print(f"FlyBase IDs have been written to {output_file}")
# Out:
# FlyBase IDs have been written to th_selected_genes.txt
