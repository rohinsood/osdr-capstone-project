# %%
# %%capture
# !pip install import_ipynb --no-cache
import import_ipynb

# %%
# %%capture
m = __import__("Methods")

# %% [markdown]
# # Feature Voting
# - Weighs the importance of features based on the frequency between models, Shapley values, and lowest RMSE

# %%
import pandas as pd
import numpy as np
import ast
from collections import defaultdict
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_colwidth', 60)

# %% [markdown]
# ### Dataset Cleaning

# %%
df = pd.read_csv("data/results/model_results_n3000.csv")

# %%
df
# Out:
#                            Model    Target Variable           MSE        RMSE  \
# 0                 ANN_Final_Test  th_positive_cells   2652.076971   51.498320
# 1   Linear_Regression_Final_Test  th_positive_cells   2042.892604   45.198369
# 2               Ridge_Final_Test  th_positive_cells   2030.433041   45.060327
# 3               Lasso_Final_Test  th_positive_cells   1986.779792   44.573308
# 4                 SVM_Final_Test  th_positive_cells   2038.254701   45.147034
# ..                           ...                ...           ...         ...
# 7   Linear_Regression_Final_Test   repo_glial_cells  50699.446595  225.165376
# 8               Ridge_Final_Test   repo_glial_cells  50730.989891  225.235410
# 9               Lasso_Final_Test   repo_glial_cells  50522.362003  224.771800
# 10                SVM_Final_Test   repo_glial_cells  50717.985908  225.206541
# 11      Random_Forest_Final_Test   repo_glial_cells  50446.581276  224.603164
#
#            MAE        R2   R  \
# 0    28.483265 -0.809668 NaN
# 1    25.071024 -0.393986 NaN
# 2    24.990324 -0.385484 NaN
# 3    24.732177 -0.355697 NaN
# 4    25.050882 -0.390821 NaN
# ..         ...       ...  ..
# 7   104.042219 -0.274177 NaN
# 8   104.083323 -0.274969 NaN
# 9   103.872901 -0.269726 NaN
# 10  104.019568 -0.274643 NaN
# 11  103.685256 -0.267822 NaN
#
#                                               Selected Features  \
# 0   7SLRNA:CR32864,abd-A,Abd-B,Abl,abo,Ace,acj6,nAChRalpha1,...
# 1   Cp38,cv-2,Dab,Dfd,disco,Delta,bsh,ea,Edg78E,Est-P,Taf9,e...
# 2   Fbp1,CG3819,GATAe,CG34002,CG5897,asRNA:CR44106,lncRNA:CR...
# 3   7SLRNA:CR32864,abd-A,Abd-B,Abl,abo,Ace,acj6,nAChRalpha1,...
# 4   Abd-B,acj6,Adh,al,amd,Argk1,Arr1,Arr2,ase,btd,by,c(3)G,C...
# ..                                                          ...
# 7   Cp19,Cp36,cv-2,CycA,CycB,Cyt-b5-r,Dab,dec,Pkg21D,Dip-B,D...
# 8   CG7126,CG43996,CG1387,CG14260,CR30409,asRNA:CR45371,CR43...
# 9   7SLRNA:CR32864,abd-A,Abd-B,Abl,abo,Ace,acj6,nAChRalpha1,...
# 10  7SLRNA:CR32864,Abd-B,Act57B,Gart,Adh,Adhr,al,amd,Amy-p,a...
# 11  7SLRNA:CR32864,abd-A,Abd-B,Abl,abo,Ace,acj6,nAChRalpha1,...
#
#                                              Sorted Shap Values
# 0   {'Fbp1': 0.6175863081031662, 'gammaTry': 0.1568093957583...
# 1   {'CG3819': 0.07599323966654625, 'Dfd': 0.055372169286853...
# 2   {'Fbp1': 0.03646496059075438, 'CG3819': 0.03262355306834...
# 3   {'snk': 0.5626258972541195, 'lncRNA:CR45188': 0.18243525...
# 4   {'Fbp1': 0.032755632660914955, 'CG3819': 0.0297635502707...
# ..                                                          ...
# 7   {'CG7126': 0.03550376790631025, 'Cp36': 0.03255355884668...
# 8   {'CG7126': 0.031388015131363314, 'CG43996': 0.0213343584...
# 9   {'ddbt': 0.43145103942503793, 'prd': 0.2957561177023954,...
# 10  {'djl': 0.035060921352132, 'Tengl3': 0.03152701489366444...
# 11  {'TpnC25D': 0.015189726512469033, 'tutl': 0.015095390673...
#
# [12 rows x 9 columns]

# %%
repo_df = df[df["Target Variable"] == "th_positive_cells"].copy()
repo_df.drop(columns=["Selected Features"], inplace=True)
repo_df
# Out:
#                           Model    Target Variable          MSE       RMSE  \
# 0                ANN_Final_Test  th_positive_cells  2652.076971  51.498320
# 1  Linear_Regression_Final_Test  th_positive_cells  2042.892604  45.198369
# 2              Ridge_Final_Test  th_positive_cells  2030.433041  45.060327
# 3              Lasso_Final_Test  th_positive_cells  1986.779792  44.573308
# 4                SVM_Final_Test  th_positive_cells  2038.254701  45.147034
# 5      Random_Forest_Final_Test  th_positive_cells  2051.461866  45.293066
#
#          MAE        R2   R  \
# 0  28.483265 -0.809668 NaN
# 1  25.071024 -0.393986 NaN
# 2  24.990324 -0.385484 NaN
# 3  24.732177 -0.355697 NaN
# 4  25.050882 -0.390821 NaN
# 5  25.037196 -0.399833 NaN
#
#                                             Sorted Shap Values
# 0  {'Fbp1': 0.6175863081031662, 'gammaTry': 0.1568093957583...
# 1  {'CG3819': 0.07599323966654625, 'Dfd': 0.055372169286853...
# 2  {'Fbp1': 0.03646496059075438, 'CG3819': 0.03262355306834...
# 3  {'snk': 0.5626258972541195, 'lncRNA:CR45188': 0.18243525...
# 4  {'Fbp1': 0.032755632660914955, 'CG3819': 0.0297635502707...
# 5  {'wbl': 0.00345565416948028, 'lncRNA:CR45809': 0.0034556...

# %% [markdown]
# ### RMSE & SHAP Summary Statistics

# %%
# Prepare lists for SHAP values and RMSE
shap_values_list = []
rmse_list = []

for index, row in repo_df.iterrows():
    # Convert SHAP values from string to actual dictionary
    shap_values = ast.literal_eval(row['Sorted Shap Values'])
    
    # Extend the list with the SHAP values
    shap_values_list.extend(shap_values.values())

    # Append the RMSE value
    rmse_list.append(row['RMSE'])

# Convert lists to pandas Series for statistical summary
shap_values_series = pd.Series(shap_values_list)
rmse_series = pd.Series(rmse_list)

# Display summary statistics
shap_stats = shap_values_series.describe()
rmse_stats = rmse_series.describe()

print("Summary Statistics for SHAP Values:")
print(shap_stats)
print("\nSummary Statistics for RMSE:")
print(rmse_stats)
# Out:
# Summary Statistics for SHAP Values:
# count    18000....
# mean      0.000733
# std       0.006868
# min       0.000000
# 25%       0.000000
# 50%       0.000055
# 75%       0.000364
# max       0.617586
# dtype: float64
#
# Summary Statistics for RMSE:
# count     6.000000
# mean     46.128404
# std       2.642762
# min      44.573308
# 25%      45.082004
# 50%      45.172702
# 75%      45.269392
# max      51.498320
# dtype: float64

# %% [markdown]
# ### Ensemble Feature Voting Implementation

# %%
from collections import defaultdict
import pandas as pd
import ast

# Create dictionaries to store feature importance and frequency
feature_importance = defaultdict(float)
feature_frequency = defaultdict(float) 

# Loop through the DataFrame and calculate importance
for index, row in repo_df.iterrows():
    shap_values = row['Sorted Shap Values']
    
    # Convert SHAP values from string to dictionary
    shap_values = ast.literal_eval(shap_values)
    rmse = row['RMSE']
    r2 = row['R2']
    
    # Weight adjustment by (1 + R²) to emphasize models with higher R² values
    weight_adjustment = (1 + r2)  # Adding 1 to ensure the weight increases with higher R²

    # scale the values, r^2 & rmse are different. weigh the performance metrics different, shap should be twice as important as the other
    for feature, shap_value in shap_values.items():
        if shap_value != 0:  # Only consider non-zero SHAP values
            # Update the feature importance based on SHAP values and R² weight
            feature_importance[feature] += shap_value * weight_adjustment
            
            # Increment the frequency for the feature, weighted by the model's RMSE and R²
            feature_frequency[feature] += (1 / rmse) * weight_adjustment  # Lower RMSE increases frequency weight

# Adjust final importance by multiplying by the RMSE and R²-weighted frequency
for feature in feature_importance:
    feature_importance[feature] *= feature_frequency[feature]

# Sort features by their adjusted importance scores
sorted_features = sorted(feature_importance.items(), key=lambda item: item[1], reverse=True)

# Create a DataFrame for the top 20 features
df_sorted_features = pd.DataFrame(sorted_features, columns=['Gene', 'Weight'])

# Display the top 20 important features
df_sorted_features.head(20)

df_sorted_features.to_csv("data/results/n3000_repo_feature_importance.csv", index=False)

# %%
df_sorted_features.head(20)
# Out:
#          Gene    Weight
# 0        Fbp1  0.007971
# 1         snk  0.006641
# 2      CG3819  0.003415
# 3   lncRNA...  0.002181
# 4     CG34002  0.001728
# ..        ...       ...
# 15    CG18480  0.000827
# 16  lncRNA...  0.000798
# 17  asRNA:...  0.000781
# 18       Ir7c  0.000761
# 19   gammaTry  0.000740
#
# [20 rows x 2 columns]

# %% [markdown]
# # Gene Set Analysis

# %%
# look at the names of the libraries that are available to use for PEA and GSEA
gene_sets = m.gp.get_library_name(organism="fly")

gene_sets.remove("Allele_Phenotypes_from_FlyBase_2017")

gene_list = df_sorted_features[:20]['Gene'].tolist()

# %%
# Perform GO enrichment analysis with FlyBase genes using Enrichr
enr = m.gp.enrichr(
    gene_list=gene_list,  # List of FlyBase gene symbols
    gene_sets=gene_sets,
    organism='fly',  # Set to 'fly' for Drosophila (FlyBase genes)
    outdir=None
)

enr.results[enr.results['Adjusted P-value'] < 0.05][['Term', 'Genes', 'Adjusted P-value']]
# Out:
#            Term      Genes  Adjusted P-value
# 0     subeso...        Dfd   0.038815
# 1     embryo...        Dfd   0.038815
# 2     intest...      GATAe   0.038815
# 3     embryo...        Dfd   0.038815
# 4     segmen...        Dab   0.038815
# ...         ...        ...        ...
# 1188  Hemocy...       Fbp1   0.006980
# 1189    Trypsin  snk;ga...   0.001768
# 1190  Hemocy...       Fbp1   0.006980
# 1191        PAX        prd   0.006980
# 1192  Homeod...    Dfd;prd   0.003294
#
# [90 rows x 3 columns]

# %%
results = enr.results[enr.results['Adjusted P-value'] < 0.05][['Term', 'Genes', 'Adjusted P-value']].sort_values(by=['Adjusted P-value'], ascending=False)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
results
# Out:
#                                                                                                                               Term  \
# 406                                          maternal specification of dorsal/ventral axis, oocyte, germ-line encoded (GO:0007311)
# 407                                                                              enteroendocrine cell differentiation (GO:0035883)
# 415                                                                          anterior/posterior pattern specification (GO:0009952)
# 429                                              positive regulation of transcription from RNA polymerase II promoter (GO:0045944)
# 434                                                               positive regulation of transcription, DNA-templated (GO:0045893)
# 403                                                                                              endoderm development (GO:0007492)
# 404                                                                         glandular epithelial cell differentiation (GO:0002067)
# 409                                                  positive regulation of apoptotic process involved in development (GO:1904747)
# 408                                                                                      digestive system development (GO:0055123)
# 410                                                                           periodic partitioning by pair rule gene (GO:0007366)
# 405                                                                                       sevenless signaling pathway (GO:0045500)
# 82                                                                                                                          embryo
# 83                                                                                                        male_reproductive_system
# 81                                                                                                                  proventriculus
# 80                                                                                                              vitelline_membrane
# 14                                                                                                                     mouth hooks
# 989                                                                                                  enhancer binding (GO:0035326)
# 13                                                                                                                maxillary palpus
# 997                                                                                    serine-type peptidase activity (GO:0008236)
# 991                                                                           activating transcription factor binding (GO:0033613)
# 1000                                                                               serine-type endopeptidase activity (GO:0004252)
# 999                                                     transcription regulatory region sequence-specific DNA binding (GO:0000976)
# 87                                                                                                                             gut
# 91                                                                                                            internal_sense_organ
# 8                                                                                                              hypostomal sclerite
# 9                                                                                                      embryonic leading edge cell
# 15                                                                                        intersegmental nerve branch ISNb of A1-7
# 12                                                                                                                       wild-type
# 11                                                                                                                            poor
# 1054                                                                                 solute:proton_symporter_activity_(GO:0015295)
# 79                                                                                                                             gut
# 10                                                                                                             pair rule phenotype
# 22                                                                                                                    male sterile
# 19                                                                                                                   denticle belt
# 0                                                                                                           subesophageal ganglion
# 1                                                                                                     embryonic mandibular segment
# 2                                                                        intestinal stem cell of posterior adult midgut epithelium
# 3                                                                                                      embryonic maxillary segment
# 4                                                                                               segmental nerve branch SNa of A1-7
# 5                                                                                                                        vibrissae
# 6                                                                                                                  lateral process
# 7                                                                                                                embryonic stage 5
# 988                                                                                                SH3 domain binding (GO:0017124)
# 996                                                                   RNA polymerase II regulatory region DNA binding (GO:0001012)
# 987                                                                                                SH2 domain binding (GO:0042169)
# 292                                                                                            inaD signaling complex (GO:0016027)
# 288                                                             vacuolar proton-transporting V-type ATPase, V1 domain (GO:0000221)
# 291                                                                                                        rhabdomere (GO:0016028)
# 290                                                                vacuolar proton-transporting V-type ATPase complex (GO:0016471)
# 289                                                                                               rhabdomere membrane (GO:0033583)
# 294                                                                                           smooth septate junction (GO:0005920)
# 295                                                                                                       microvillus (GO:0005902)
# 283                                                                         proton-transporting V-type ATPase complex (GO:0033176)
# 284                                                                      proton-transporting V-type ATPase, V1 domain (GO:0033180)
# 293                                                                                              microvillus membrane (GO:0031528)
# 287                                                                                            rhabdomere microvillus (GO:0035996)
# 286                                                         plasma membrane proton-transporting V-type ATPase complex (GO:0033181)
# 285                                                                              endoplasmic reticulum subcompartment (GO:0098827)
# 994   transcriptional activator activity, RNA polymerase II transcription regulatory region sequence-specific binding (GO:0001228)
# 1131                                                                                                               prostate cancer
# 1137                                                                                                      Homeobox domain, metazoa
# 992                                                 RNA polymerase II regulatory region sequence-specific DNA binding (GO:0000977)
# 990                        transcription factor activity, RNA polymerase II distal enhancer sequence-specific binding (GO:0003705)
# 964                                                                                            protein_kinase_complex_(GO:1902911)
# 95                                                                                      ceramide biosynthetic process (GO:0046513)
# 94                                                                                                   cold acclimation (GO:0009631)
# 96                                                                                            protein deglycosylation (GO:0006517)
# 104                                                                                                   anion transport (GO:0006820)
# 102                                                                              toll-like receptor signaling pathway (GO:0002224)
# 99                                                                                     sphingolipid catabolic process (GO:0030149)
# 93                                                                                            lipid catabolic process (GO:0016042)
# 103                                                                                            vacuolar acidification (GO:0007035)
# 101                                                                                             inflammatory response (GO:0006954)
# 100                                                                                     vesicle budding from membrane (GO:0006900)
# 98                                                                                          mannose metabolic process (GO:0006013)
# 97                                                                                         intracellular pH reduction (GO:0051452)
# 92                                                                                                        proteolysis (GO:0006508)
# 1135                                                                                                        Hemocyanin, N-terminal
# 1139                                                                                                                 PTB/PI domain
# 1138                                                                                            Proteinase, regulatory CLIP domain
# 1140                                                                                                                 Paired domain
# 1134                                                                                                        Hemocyanin, C-terminal
# 1191                                                                                                                           PAX
# 1190                                                                                                                  Hemocyanin_N
# 1188                                                                                                                  Hemocyanin_C
# 1141                                                                                                               Homeobox domain
# 977                                                                                            protein_kinase_complex_(GO:1902911)
# 1192                                                                                                                   Homeodomain
# 1136                                                                                              Serine proteases, trypsin domain
# 1189                                                                                                                       Trypsin
#
#                      Genes  Adjusted P-value
# 406                    snk          0.048905
# 407                  GATAe          0.048905
# 415                prd;Dfd          0.048905
# 429          prd;Dfd;GATAe          0.048905
# 434          prd;Dfd;GATAe          0.048905
# 403                  GATAe          0.048905
# 404                  GATAe          0.048905
# 409                    Dfd          0.048905
# 408                  GATAe          0.048905
# 410                    prd          0.048905
# 405                    Dab          0.048905
# 82                   GATAe          0.045788
# 83                     prd          0.045788
# 81                   GATAe          0.045788
# 80                     snk          0.045788
# 14                     Dfd          0.045070
# 989                    Dfd          0.043245
# 13                     Dfd          0.043217
# 997           snk;gammaTry          0.042853
# 991                    Dfd          0.042853
# 1000          snk;gammaTry          0.042853
# 999                Dfd;prd          0.042853
# 87           CG18480;GATAe          0.041988
# 91                 Dfd;Dab          0.041988
# 8                      Dfd          0.041124
# 9                      Dab          0.041124
# 15                     Dab          0.041124
# 12                     prd          0.041124
# 11                     Dfd          0.041124
# 1054  CG3819;CG18480;GATAe          0.040613
# 79                   GATAe          0.039924
# 10                     prd          0.038815
# 22                 prd;Dab          0.038815
# 19                 snk;prd          0.038815
# 0                      Dfd          0.038815
# 1                      Dfd          0.038815
# 2                    GATAe          0.038815
# 3                      Dfd          0.038815
# 4                      Dab          0.038815
# 5                      Dfd          0.038815
# 6                      Dfd          0.038815
# 7                      Dab          0.038815
# 988                    Dab          0.035863
# 996                Dfd;prd          0.035863
# 987                    Dab          0.035863
# 292                Dfd;Dab          0.033590
# 288           CG3819;GATAe          0.033590
# 291                Dfd;Dab          0.033590
# 290           CG3819;GATAe          0.033590
# 289                Dfd;Dab          0.033590
# 294           CG3819;GATAe          0.033590
# 295                Dfd;Dab          0.033590
# 283           CG3819;GATAe          0.033590
# 284           CG3819;GATAe          0.033590
# 293                Dfd;Dab          0.033590
# 287                Dfd;Dab          0.033590
# 286           CG3819;GATAe          0.033590
# 285                Dfd;Dab          0.033590
# 994              Dfd;GATAe          0.030789
# 1131                   prd          0.026898
# 1137                   Dfd          0.024717
# 992          Dfd;prd;GATAe          0.021466
# 990                Dfd;prd          0.021466
# 964          Dfd;Dab;GATAe          0.021046
# 95    CG3819;CG18480;GATAe          0.014554
# 94    CG3819;CG18480;GATAe          0.014554
# 96    CG3819;CG18480;GATAe          0.014554
# 104   CG3819;CG18480;GATAe          0.014554
# 102   CG3819;CG18480;GATAe          0.014554
# 99    CG3819;CG18480;GATAe          0.014554
# 93    CG3819;CG18480;GATAe          0.014554
# 103   CG3819;CG18480;GATAe          0.014554
# 101   CG3819;CG18480;GATAe          0.014554
# 100   CG3819;CG18480;GATAe          0.014554
# 98    CG3819;CG18480;GATAe          0.014554
# 97    CG3819;CG18480;GATAe          0.014554
# 92    CG3819;CG18480;GATAe          0.014554
# 1135                  Fbp1          0.009113
# 1139                   Dab          0.009113
# 1138                   snk          0.009113
# 1140                   prd          0.009113
# 1134                  Fbp1          0.009113
# 1191                   prd          0.006980
# 1190                  Fbp1          0.006980
# 1188                  Fbp1          0.006980
# 1141               Dfd;prd          0.005868
# 977              Dfd;GATAe          0.005820
# 1192               Dfd;prd          0.003294
# 1136          snk;gammaTry          0.002828
# 1189          snk;gammaTry          0.001768

# %% [markdown]
# # Pathway Analysis Prep

# %%
symbols = df_sorted_features["Gene"].to_list()

import pandas as pd

# Load the conversion DataFrame
conversion_df = pd.read_csv("conversion_df.csv")

# Assuming the columns in conversion_df are named 'GeneSymbol' and 'FlyBaseID'
# If they have different names, adjust accordingly.
conversion_dict = dict(zip(conversion_df['Gene Symbol'], conversion_df['FB ID']))

# Assuming `symbols` contains the gene symbols
flybase_ids = [conversion_dict.get(symbol) for symbol in symbols]

# Now `flybase_ids` contains the FlyBase IDs corresponding to the gene symbols.
flybase_ids[:20]
# Out:
# ['FBgn0000639',
#  'FBgn0003450',
#  'FBgn0036833',
#  'FBgn0266698',
#  'FBgn0054002',
#  'FBgn0286834',
#  'FBgn0000439',
#  'FBgn0036220',
#  'FBgn0003145',
#  'FBgn0264915',
#  'FBgn0000414',
#  'FBgn0266436',
#  'FBgn0038391',
#  'FBgn0265982',
#  'FBgn0034563',
#  'FBgn0028518',
#  'FBgn0047092',
#  'FBgn0266628',
#  'FBgn0029966',
#  'FBgn0010359']

# %%
# Specify the output file name
output_file = "background_genes.txt"

# Write the FlyBase IDs to the text file
with open(output_file, 'w') as file:
    for fb_id in conversion_df["FB ID"]:
        file.write(f"{fb_id}\n")

print(f"FlyBase IDs have been written to {output_file}")
# Out:
# FlyBase IDs have been written to background_genes.txt

# %%
# Specify the output file name
output_file = "th_selected_genes.txt"

# Write the FlyBase IDs to the text file
with open(output_file, 'w') as file:
    for fb_id in flybase_ids:
        file.write(f"{fb_id}\n")

print(f"FlyBase IDs have been written to {output_file}")
# Out:
# FlyBase IDs have been written to repo_selected_genes.txt
